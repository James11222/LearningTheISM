# %%
import os

# %% [markdown]
# # Acquire Data
#
# We pull data from the CATS collaboration which hosts MHD ISM simulations with varying magnetic field strength and pressure values corresponding to different Mach Numbers and Alfvénic Mach Numbers.
#
# We will use this data in our analysis to study the ISM with the 4PCF.

# %% [markdown]
# $$\mathcal{M}_s \sim 0.7$$
# $$\mathcal{M}_A \sim 0.7$$

# %%
# !wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p1/t_800/dens_t800.fits.gz
# !ls

for i in range(500, 901, 50):
    os.system(f'wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p1/t_{i}/dens_t{i}.fits.gz')
    
os.system(f'mv dens_*.fits.gz Ms_0p7__Ma_0p7')
# Out:
# zsh:1: parse error near `do'
# --2023-02-25 09:16:28--  https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p1/t_/dens_.fits.gz
# Resolving users.flatironinstitute.org (users.flatironinstitute.org)... 144.121.86.9
# Connecting to users.flatironinstitute.org (users.flatironinstitute.org)|144.121.86.9|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-25 09:16:28 ERROR 404: Not Found.
#
# zsh:1: parse error near `done'
# zsh:1: no matches found: dens*.fits.gz

# %% [markdown]
# $$\mathcal{M}_s \sim 2.0$$
# $$\mathcal{M}_A \sim 0.7$$

# %%
# !wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p.1/t_800/dens_t800.fits.gz
# !ls

for i in range(500, 901, 50):
    os.system(f'wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p.1/t_{i}/dens_t{i}.fits.gz')
    
os.system(f'mv dens_*.fits.gz Ms_2p0__Ma_0p7')
# Out:
# --2023-02-25 09:24:35--  https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b1p.1/t_500/dens_t500.fits.gz
# Resolving users.flatironinstitute.org (users.flatironinstitute.org)... 144.121.86.9
# Connecting to users.flatironinstitute.org (users.flatironinstitute.org)|144.121.86.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59816349 (57M) [application/octet-stream]
# Saving to: 'dens_t500.fits.gz'
#
#      0K .......... .......... .......... .......... ..........  0%  564K 1m44s
#     50K .......... .......... .......... .......... ..........  0%  722K 92s
#    100K .......... .......... .......... .......... ..........  0% 5.54M 65s
#    150K .......... .......... .......... .......... ..........  0%  702K 69s
#    200K .......... .......... .......... .......... ..........  0% 4.81M 58s
#    250K .......... .......... .......... .......... ..........  0% 41.9M 48s
# ...

# %% [markdown]
# $$\mathcal{M}_s \sim 0.7$$
# $$\mathcal{M}_A \sim 2.0$$

# %%
# !wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p1/t_800/dens_t800.fits.gz
# !ls

for i in range(500, 901, 50):
    os.system(f'wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p1/t_{i}/dens_t{i}.fits.gz')
    
os.system(f'mv dens_*.fits.gz Ms_0p7__Ma_2p0')
# Out:
# --2023-02-25 09:25:15--  https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p1/t_500/dens_t500.fits.gz
# Resolving users.flatironinstitute.org (users.flatironinstitute.org)... 144.121.86.9
# Connecting to users.flatironinstitute.org (users.flatironinstitute.org)|144.121.86.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56947449 (54M) [application/octet-stream]
# Saving to: 'dens_t500.fits.gz'
#
#      0K .......... .......... .......... .......... ..........  0%  595K 93s
#     50K .......... .......... .......... .......... ..........  0%  629K 91s
#    100K .......... .......... .......... .......... ..........  0% 17.9M 61s
#    150K .......... .......... .......... .......... ..........  0%  671K 67s
#    200K .......... .......... .......... .......... ..........  0% 7.94M 55s
#    250K .......... .......... .......... .......... ..........  0%  112M 46s
# ...

# %% [markdown]
# $$\mathcal{M}_s \sim 2.0$$
# $$\mathcal{M}_A \sim 2.0$$

# %%
# !wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p.1/t_800/dens_t800.fits.gz
# !ls

for i in range(500, 901, 50):
    os.system(f'wget https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p.1/t_{i}/dens_t{i}.fits.gz')
    
os.system(f'mv dens_*.fits.gz Ms_2p0__Ma_2p0')
# Out:
# --2023-02-25 09:26:13--  https://users.flatironinstitute.org/~bburkhart/data/CATS/MHD/256/b.1p.1/t_500/dens_t500.fits.gz
# Resolving users.flatironinstitute.org (users.flatironinstitute.org)... 144.121.86.9
# Connecting to users.flatironinstitute.org (users.flatironinstitute.org)|144.121.86.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59840804 (57M) [application/octet-stream]
# Saving to: 'dens_t500.fits.gz'
#
#      0K .......... .......... .......... .......... ..........  0%  675K 86s
#     50K .......... .......... .......... .......... ..........  0%  649K 88s
#    100K .......... .......... .......... .......... ..........  0% 3.47M 64s
#    150K .......... .......... .......... .......... ..........  0%  750K 68s
#    200K .......... .......... .......... .......... ..........  0% 53.4M 54s
#    250K .......... .......... .......... .......... ..........  0% 3.55M 48s
# ...
